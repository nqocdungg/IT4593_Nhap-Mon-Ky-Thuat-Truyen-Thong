# %%
import numpy as np
import matplotlib.pyplot as plt
import time

# ============================
#  THUẬT TOÁN CABC (có global_best)
# ============================
start = time.time()

N = 6
D = 2
SN = N // 2
LIMIT = (N * D) // 2
MAX_ITER = 500   # m đang để 500, giữ nguyên; nếu muốn so công bằng thì cho = 50

bounds = np.array([
    [0.5, 1.5],
    [1.5, 2.5]
])

# Tham số logistic map
mu = 4
z = np.random.rand()   # z0 ban đầu

def chaotic():
    """Sinh số hỗn loạn trong (0,1) theo logistic map."""
    global z
    z = mu * z * (1 - z)
    return z

# ========== KHỞI TẠO HỖN LOẠN ==========
food_sources = np.zeros((SN, D))
for i in range(SN):
    for j in range(D):
        c = chaotic()
        food_sources[i, j] = bounds[j][0] + c * (bounds[j][1] - bounds[j][0])

trial = np.zeros(SN, dtype=int)

# ========== HÀM MỤC TIÊU & FITNESS ==========
def objective(x):
    return (x[0] - 1)**2 + (x[1] - 2)**2 + 3

def fitness_func(f):
    return 1/(1+f)   # f luôn >= 3 trong bài toán này


# ========== SINH NGHIỆM MỚI CABC ==========
def generate_new_solution_cabc(i):
    k = np.random.randint(D)
    j = np.random.choice([a for a in range(SN) if a != i])

    z_loc = chaotic()
    # map về [-1,1], rồi giảm biên độ (0.7)
    phi = (2*z_loc - 1) * 0.7

    v = food_sources[i].copy()
    v[k] = v[k] + phi * (v[k] - food_sources[j][k])

    return np.clip(v, bounds[:, 0], bounds[:, 1])


# ========== KHỞI TẠO FITNESS + GLOBAL BEST ==========
fitness = np.array([fitness_func(objective(x)) for x in food_sources])

best_idx = np.argmax(fitness)
global_best_x = food_sources[best_idx].copy()
global_best_f = objective(global_best_x)

history_cabc = []

print("\n================ CABC: KHỞI TẠO ================")
for i, fs in enumerate(food_sources):
    print(f"  X{i} = {fs}, f(X{i}) = {objective(fs):.4f}")
print("  → Global best ban đầu:", global_best_x, ", f =", global_best_f)


# ========== VÒNG LẶP CABC ==========
for iteration in range(1, MAX_ITER + 1):

    # --- Ong thợ ---
    for i in range(SN):
        v = generate_new_solution_cabc(i)

        f_new = objective(v)
        f_old = objective(food_sources[i])
        fit_new = fitness_func(f_new)
        fit_old = fitness_func(f_old)

        if fit_new > fit_old:
            food_sources[i] = v
            fitness[i] = fit_new
            trial[i] = 0
        else:
            trial[i] += 1

    # --- Ong quan sát ---
    prob = fitness / np.sum(fitness)

    for _ in range(SN):
        i = np.random.choice(range(SN), p=prob)
        v = generate_new_solution_cabc(i)

        f_new = objective(v)
        f_old = objective(food_sources[i])
        fit_new = fitness_func(f_new)
        fit_old = fitness_func(f_old)

        if fit_new > fit_old:
            food_sources[i] = v
            fitness[i] = fit_new
            trial[i] = 0
        else:
            trial[i] += 1

    # --- Ong do thám ---
    for i in range(SN):
        if trial[i] > LIMIT:
            for j in range(D):
                c = chaotic()
                food_sources[i][j] = bounds[j][0] + c * (bounds[j][1] - bounds[j][0])
            trial[i] = 0
            fitness[i] = fitness_func(objective(food_sources[i]))

    # --- CẬP NHẬT GLOBAL BEST ---
    best_idx = np.argmax(fitness)
    current_best_x = food_sources[best_idx].copy()
    current_best_f = objective(current_best_x)

    if current_best_f < global_best_f:
        global_best_f = current_best_f
        global_best_x = current_best_x.copy()

    history_cabc.append(global_best_f)
    print(f"Iteration {iteration:3d}: global best f(x) = {global_best_f:.6f}, gbest = {global_best_x}")

end = time.time()

print("\n=== KẾT QUẢ CUỐI CÙNG (CABC) ===")
print("Global best ≈", global_best_x)
print("f(Global best) ≈", global_best_f)
print(f"Thời gian chạy CABC: {end - start:.6f} giây")

# ========== VẼ ĐỒ THỊ HỘI TỤ ==========
plt.plot(history_cabc, marker='o')
plt.xlabel("Iteration")
plt.ylabel("Global best f(x)")
plt.title("Convergence Curve of CABC (global best)")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ================ CABC: KHỞI TẠO ================
#   X0 = [1.27601539 2.19526201], f(X0) = 3.1143
#   X1 = [1.34749099 2.01700004], f(X1) = 3.1210
#   X2 = [1.498844   1.50461867], f(X2) = 3.4942
#   → Global best ban đầu: [1.27601539 2.19526201] , f = 3.1143117496563457
# Iteration   1: global best f(x) = 3.087818, gbest = [1.22291391 2.19526201]
# Iteration   2: global best f(x) = 3.031619, gbest = [1.15740035 1.91726868]
# Iteration   3: global best f(x) = 3.016018, gbest = [1.09577982 1.91726868]
# Iteration   4: global best f(x) = 3.016018, gbest = [1.09577982 1.91726868]
# Iteration   5: global best f(x) = 3.010382, gbest = [1.05947455 1.91726868]
# Iteration   6: global best f(x) = 3.006921, gbest = [0.99124843 1.91726868]
# Iteration   7: global best f(x) = 3.006423, gbest = [0.99124843 1.92033383]
# Iteration   8: global best f(x) = 3.006423, gbest = [0.99124843 1.92033383]
# Iteration   9: global best f(x) = 3.006423, gbest = [0.99124843 1.92033383]
# Iteration  10: global best f(x) = 3.006423, gbest = [0.99124843 1.92033383]
# Iteration  11: global best f(x) = 3.002023, gbest = [1.03847914 1.97670541]
# Iteration  12: global best f(x) = 3.002023, gbest = [1.03847914 1.97670541]
# Iteration  13: global best f(x) = 3.001777, gbest = [1.03847914 2.01721554]
# Iteration  14: global best f(x) = 3.000111, gbest = [0.99067173 1.99510258]
# Iteration  15: global best f(x) = 3.000111, gbest = [0.99067173 1.99510258]
# Iteration  16: global best f(x) = 3.000017, gbest = [1.0038592  2.00128415]
# Iteration  17: global best f(x) = 3.000016, gbest = [1.0038592  2.00079627]
# Iteration  18: global best f(x) = 3.000016, gbest = [1.0038592  2.00079627]
# Iteration  19: global best f(x) = 3.000001, gbest = [0.99963839 2.00097626]
# Iteration  20: global best f(x) = 3.000001, gbest = [0.99963839 2.00097626]
# Iteration  21: global best f(x) = 3.000001, gbest = [0.99963839 2.00095535]
# Iteration  22: global best f(x) = 3.000001, gbest = [0.99963839 2.00095535]
# Iteration  23: global best f(x) = 3.000001, gbest = [0.99963839 2.00095535]
# Iteration  24: global best f(x) = 3.000001, gbest = [0.99963839 2.00095535]
# Iteration  25: global best f(x) = 3.000001, gbest = [0.99963839 2.00095535]
# Iteration  26: global best f(x) = 3.000001, gbest = [0.99963839 2.00095535]
# Iteration  27: global best f(x) = 3.000001, gbest = [0.99963839 2.00095535]
# Iteration  28: global best f(x) = 3.000001, gbest = [0.99963839 2.00095535]
# Iteration  29: global best f(x) = 3.000001, gbest = [0.99963839 2.00095535]
# Iteration  30: global best f(x) = 3.000001, gbest = [0.99963839 2.00095535]
# Iteration  31: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  32: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  33: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  34: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  35: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  36: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  37: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  38: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  39: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  40: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  41: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  42: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  43: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  44: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  45: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  46: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  47: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  48: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  49: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  50: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  51: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  52: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  53: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  54: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  55: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  56: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  57: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  58: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  59: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  60: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  61: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  62: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  63: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  64: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  65: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  66: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  67: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  68: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  69: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  70: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  71: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  72: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  73: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  74: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  75: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  76: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  77: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  78: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  79: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  80: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  81: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  82: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  83: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  84: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  85: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  86: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  87: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  88: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  89: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  90: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  91: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  92: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  93: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  94: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  95: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  96: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  97: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  98: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration  99: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration 100: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration 101: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration 102: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration 103: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration 104: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration 105: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration 106: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration 107: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration 108: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration 109: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration 110: global best f(x) = 3.000001, gbest = [1.00009833 2.0009334 ]
# Iteration 111: global best f(x) = 3.000000, gbest = [1.00009952 1.99971603]
# Iteration 112: global best f(x) = 3.000000, gbest = [1.00009952 1.99989272]
# Iteration 113: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 114: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 115: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 116: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 117: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 118: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 119: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 120: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 121: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 122: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 123: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 124: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 125: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 126: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 127: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 128: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 129: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 130: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 131: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 132: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 133: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 134: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 135: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 136: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 137: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 138: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 139: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 140: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 141: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 142: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 143: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 144: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 145: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 146: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 147: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 148: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 149: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 150: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 151: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 152: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 153: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 154: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 155: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 156: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 157: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 158: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 159: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 160: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 161: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 162: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration 163: global best f(x) = 3.000000, gbest = [1.00009952 1.99993155]
# Iteration